# %%
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.optim as optim

# hyped to build on jupyter notebooks now

# %%
# when you guys are running this
# change device to what works for you
# i think mps is for ARM based macs
# cuda is for Nvidia based stuff i think (might be wrong abt this though)
# cpu is for everyone else

device = torch.device('mps')

# %%
# we need data now
